# %%
import numpy as np

from matplotlib import pyplot as plt

# %%
from nbodykit.source.catalog import ArrayCatalog
from nbodykit.lab import FFTPower

# %%
from abacusnbody.data.compaso_halo_catalog import CompaSOHaloCatalog

# %%
def measure_pkl(pos, uzs, Lbox=2000, nc=128, dk=0.005, los=0):

    hpos = 1.0 * pos
    hpos[:,los] += uzs[:,los]

    data = {'Position':hpos}
    hcat = ArrayCatalog(data)
    hmesh = hcat.to_mesh(Nmesh=nc, BoxSize=Lbox, compensated=True, window='tsc',interlaced=True)

    r = FFTPower(hmesh, mode='2d',poles=[0,2,4],los=[0,0,1],Nmu=5, dk=dk)    
    k, Nk, p0k, p2k, p4k = r.poles['k'], r.poles['modes'], r.poles['power_0'].real, r.poles['power_2'].real, r.poles['power_4'].real

    sn = r.power.attrs['shotnoise']

    return k, p0k, p2k, p4k, sn, Nk, r, hmesh

# %%
def measure_pnm(pos, us, Lbox=2000, nc=128, dk=0.005, max_order = 4, redshift_space=False, los=2):

    hpos = 1.0 * pos

    if redshift_space:
        hpos[:,los] += us[:,los]

    # force back into box:
    iis = hpos[:,los] > Lbox/2
    hpos[iis,los] -= Lbox

    iis = hpos[:,los] < -Lbox/2
    hpos[iis,los] += Lbox
    
    data = {'Position':hpos}
    hcat = ArrayCatalog(data)
    
    meshes = []
    
    for ii in range(max_order+1):
        vel_name = 'u%d'%(ii)
        hcat[vel_name] = us[:,los]**ii
        meshes += [hcat.to_mesh(Nmesh=nc, BoxSize=Lbox, compensated=True, window='tsc', interlaced=True, position='Position',value=vel_name),]

    ret = []

    ells = [0, 1, 2, 3, 4]
    
    for vel_order in range(max_order+1):

        #print("Now computing spectra with %d velocities"%(vel_order))
    
        counter = 0
        data = []
        #header = ''
        for ii in range(vel_order+1):
            jj = vel_order - ii
            
            if jj >= ii: # only distinct pairs
                #header += ' (%d,%d) |'%(ii,jj)
                nvec = np.array([0,0,0])
                nvec[los] = 1
                rij = FFTPower(meshes[jj], mode='1d', poles=list(ells), second=meshes[ii], los=nvec,dk=dk) 
            
                if counter == 0:
                    data += [rij.poles['k'],]
            
                if vel_order%2 == 0:
                    data += [ rij.poles['power_%d'%(ell)].real for ell in ells ]
                else:
                    data += [ rij.poles['power_%d'%(ell)].imag for ell in ells ]
            
                counter += 1
        
        ret += [data,]
    
    return ret

# %%
basedir = '/global/cfs/cdirs/desi/public/cosmosim/AbacusSummit/'

# %%
logMmin = 12.5
logMmax = 13.0
z = 0.1

# %%
for ii in range(1):

    print(ii)
    
    sample = f'AbacusSummit_base_c000_ph{ii:03}/halos/z{z:.3f}'
    filename = basedir + sample

    cat = CompaSOHaloCatalog(basedir+sample,fields=('x_com','v_com','N'))
    
    particle_mass = cat.header['ParticleMassHMsun'] # / (cat.header['H0']/100)
    Ms = cat.halos['N'] * particle_mass
    mass_iis = (Ms > 10.**logMmin) * (Ms < 10**logMmax)
    cat.halos = cat.halos[mass_iis]

    Lbox = cat.header['BoxSize']
    nc = 256

    OmegaM = cat.header['Omega_M']
    z = cat.header['Redshift']
    Ez = np.sqrt(OmegaM * (1+z)**3 + 1 - OmegaM)
    vfac = 0.01 * (1 + z) / Ez # convert km/s to h^{-1} Mpc, u = v / (aH) = v * (1+z) / (100 * E(z))
    uz = cat.halos['v_com'] * vfac


    res = measure_pkl(cat.halos['x_com'], uz, Lbox=Lbox, nc=nc, dk=0.005)

print(res)
# Out:
# 0
# /global/homes/s/sfschen/.conda/envs/nbodykit_env/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: The window argument is deprecated. Use `resampler=` instead
# 0.45124655961990356
# (array([0.00379811, 0.00829934, 0.01293223, 0.0176484 , 0.02256549,
#        0.02777644, 0.03269805, 0.03761648, 0.04263844, 0.04756515,
#        0.05262096, 0.05756032, 0.06254738, 0.06757793, 0.07255918,
#        0.07753384, 0.08251793, 0.08752752, 0.09254702, 0.09754963,
#        0.10253196, 0.1075116 , 0.11251029, 0.11755009, 0.12253694,
#        0.1275261 , 0.13253021, 0.13750627, 0.14251344, 0.14752592,
#        0.15252994, 0.15749457, 0.16251893, 0.1675461 , 0.1725292 ,
#        0.1775302 , 0.18251477, 0.18753607, 0.19253237, 0.19751987,
#        0.20251537, 0.20750885, 0.21251781, 0.21750042, 0.22250932,
#        0.22752896, 0.23252854, 0.23752766, 0.2424991 , 0.24749986,
#        0.25252003, 0.25751823, 0.26252557, 0.26753055, 0.27254046,
#        0.27753332, 0.28251239, 0.28751047, 0.29249713, 0.29750588,
#        0.30251214, 0.30750104, 0.31251342, 0.31751597, 0.32252214,
#        0.32751817, 0.33251238, 0.33749594, 0.34249192, 0.34751798,
#        0.35250529, 0.35751333, 0.36252502, 0.36752304, 0.37251771,
#        0.3775163 , 0.38252269, 0.38751301, 0.39249579, 0.39750647]), array([12111.48848684, 33823.39453125, 36521.5       , 35358.93150685,
#        35700.40831758, 31454.5902439 , 27652.28      , 24129.9312205 ,
#        22482.81473214, 20506.56955953, 18765.69662921, 16988.96782178,
#        16054.49300957, 15129.57293497, 14380.26111214, 13486.95413458,
#        12124.62614679, 11147.37644162, 10189.77484047,  9273.04427928,
#         8841.92120075,  8268.0206754 ,  7819.10056427,  7628.69577585,
#         7286.61290963,  7023.78850352,  6620.25161327,  6339.94846885,
#         6014.29986562,  5830.57086883,  5453.48934731,  5218.5054394 ,
#         5059.30277372,  4799.91571754,  4672.84912813,  4516.23069157,
#         4338.03633785,  4274.33251397,  4145.17296776,  4017.26672569,
#         3883.59008009,  3751.05342463,  3667.8352243 ,  3579.65154448,
#         3466.97220307,  3402.92637379,  3286.39528496,  3217.10304096,
#         3170.86002735,  3084.73083573,  3025.14321064,  2946.64659861,
#         2884.86289724,  2834.22896674,  2779.12286455,  2728.20265205,
#         2670.10229111,  2632.93123923,  2552.41031569,  2540.07175206,
#         2494.97194241,  2454.06239222,  2396.48952343,  2387.4211276 ,
#         2344.73369832,  2302.7977786 ,  2281.54973002,  2257.12447886,
#         2224.80807407,  2186.08645081,  2158.79520996,  2141.07962689,
#         2103.30516488,  2084.02516604,  2063.71387729,  2033.36112701,
#         2010.69664865,  2002.38040042,  1960.81228076,  1944.81610805]), array([  5662.93585526,  -2006.23828125,  -8154.56687898,  -7695.3390411 ,
#         -9194.89224953, -11439.12682927,  -8324.72      ,  -6183.86109238,
#         -6958.89955357,  -5660.60008722,  -5578.66011236,  -5216.2029703 ,
#         -4089.39906794,  -3340.73286467,  -3926.1164218 ,  -3912.99229997,
#         -2729.60321101,  -2578.35117274,  -2230.69097539,  -2131.68805611,
#         -2000.66716698,  -1865.4555479 ,  -1674.10682538,  -1818.23979519,
#         -1418.58245614,  -1392.44482173,  -1246.30222771,  -1457.68278775,
#         -1165.43367249,  -1140.09786323,  -1117.33310788,   -930.24402475,
#          -868.89138686,   -913.988041  ,   -932.02966674,   -802.22488642,
#          -725.30071789,   -766.00089385,   -691.76159366,   -723.67836095,
#          -656.67007623,   -720.35100414,   -605.66451388,   -537.3285077 ,
#          -572.78650933,   -537.85427828,   -495.53257053,   -493.02780805,
#          -529.26659126,   -433.74396414,   -386.04689143,   -408.3844721 ,
#          -363.81286016,   -354.98057193,   -303.63844079,   -358.54400703,
#          -343.72106466,   -321.10706761,   -313.89751355,   -318.318977  ,
#          -303.87843154,   -270.45894341,   -245.24029761,   -280.4079732 ,
#          -244.56243157,   -247.3501666 ,   -232.69790156,   -221.86469537,
#          -219.629066  ,   -187.18280132,   -204.56164777,   -192.81035632,
#          -179.36973347,   -168.10305536,   -172.88032478,   -173.21430689,
#          -160.61686486,   -143.83645943,   -155.99518553,   -133.03681308]), array([ 3.91021842e+04,  6.08316113e+03, -6.85839968e+03,  5.14896190e+03,
#        -6.70280813e+03, -1.49340915e+03, -7.08192000e+03,  1.84432670e+03,
#        -8.05993304e+02, -3.84270388e+02, -9.05126404e+01,  5.38078899e+02,
#        -9.40156978e+01,  2.40738576e+02, -4.93918542e+01,  3.53477737e+02,
#        -3.69243119e+02,  5.78579241e+02, -1.00174339e+02,  3.70329739e+01,
#         5.70318949e+00, -3.75381806e+02,  2.54181495e+02,  2.47770161e+02,
#        -7.41738497e+01,  7.21528014e+01, -3.92826441e+01,  3.60373495e+02,
#         6.22021501e+01, -4.78157547e+01,  3.57363375e+02, -1.49704534e+02,
#         1.47915912e+02, -3.17253702e+01,  6.87439101e+01,  1.23681853e+02,
#         3.76105646e+00,  1.20620112e+02,  4.78842241e+01,  1.53549412e+02,
#         5.32522436e+01,  1.41839108e+02,  9.19126375e+01, -6.38293915e+01,
#         7.33040720e+01,  4.41079137e+01,  5.45087225e+01,  7.63954298e+01,
#         1.00613509e+02,  7.32602626e+01,  1.45932570e-01,  5.80690560e+01,
#        -3.81605523e+00,  1.25184132e+01,  4.75575713e+01,  3.71931657e+01,
#         8.45436917e+01,  3.94403850e+01, -4.33465189e+01,  3.08589823e+01,
#         1.93319787e+01,  7.26849976e+01,  2.20281520e+00,  7.18991266e+01,
#         2.30365112e+01,  1.83058127e+00,  5.98116655e+01, -2.73173808e+00,
#         3.61689155e+01,  5.95471297e+01,  3.76784289e+00,  2.93255053e+01,
#         1.30863123e+01,  3.28364864e+01,  3.13242038e+01,  3.47191372e+01,
#         5.98403243e+01,  9.35326660e+00,  1.44352718e+01,  7.10488817e+00]), 1056.7109001446506, array([    19,    128,    314,    584,   1058,   1640,   2000,   2966,
#          3584,   4586,   5696,   6464,   8154,   9104,  10754,  11948,
#         13952,  15434,  17552,  19106,  21320,  23216,  25874,  28124,
#         30210,  32984,  35642,  37880,  41672,  43898,  47312,  49454,
#         54800,  56192,  60674,  63392,  67698,  71600,  74696,  79070,
#         82904,  87338,  91664,  95048, 101522, 104528, 109946, 113780,
#        118466, 124920, 129320, 134210, 140216, 144842, 151256, 154748,
#        161930, 167072, 173018, 180176, 185048, 191370, 198920, 203582,
#        211880, 216080, 224834, 228344, 239978, 244856, 250520, 260942,
#        265640, 274338, 279824, 290042, 296000, 303680, 310730, 322820]), <nbodykit.algorithms.fftpower.FFTPower object at 0x7f230d34f310>, (ArrayCatalog(size=7570661) as CatalogMesh))

# %%
cat.header
# Out:
# {'AllowGroupFinding': 1,
#  'BackupDirectory': '/gpfs/alpine/proj-shared/ast145/AbacusSummit/AbacusSummit_base_c000_ph000',
#  'BackupStepInterval': -1,
#  'BoxSize': 2000.0,
#  'BoxSizeHMpc': 2000.0,
#  'BoxSizeMpc': 2969.1211401425176,
#  'CPD': 1701,
#  'CodeVersion': '8d43e2d166b9bcb0168a6ca49a4643d06bfb2625',
#  'Conv_IOCores': 0,
#  'Conv_IOMode': 'overwrite',
#  'Conv_OMP_NUM_THREADS': 42,
#  'Conv_OMP_PLACES': '{0}:21:4,{88}:21:4',
#  'Conv_OMP_PROC_BIND': 'spread',
#  'Conv_zwidth': 0,
#  'ConvolutionCacheSizeMB': 200,
#  'ConvolutionL1CacheSizeMB': 0.015625,
#  'CoordinateDistanceHMpc': 292.5861830707283,
#  'DeleteICsAfterFirstBackup': 1,
#  'DeltaEtaDrift': 0.0007023815099787001,
#  'DeltaRedshift': 0.000670922877507,
#  'DeltaScaleFactor': 0.000554143728125,
#  'DeltaTime': 0.000580126734663,
#  'DensityKernelRad': 0.4,
#  'DensityKernelRad2': 3.34898e-09,
#  'DerivativeExpansionRadius': 8,
#  'DerivativesDirectory': '/gpfs/alpine/proj-shared/ast145/Derivatives',
#  'DirectBPD': 2,
#  'Do2LPTVelocityRereading': 0,
#  'DoublePrecision': 0,
#  'FinalRedshift': 0.1,
#  'FirstHalfEtaKick': 0.0003192156461468976,
#  'FoFLinkingLength': [0.25, 0.25, 0.25],
#  'FullStepNumber': 1106,
#  'GPUQueueAssignments': [0, 0, 0, 1, 1, 1],
#  'GPUThreadCoreStart': [72, 76, 80, 160, 164, 168],
#  'GroupDirectory': '/gpfs/alpine/proj-shared/ast145/AbacusSummit/AbacusSummit_base_c000_ph000/group',
#  'GroupRadius': 10,
#  'Growth': 0.747802609695575,
#  'Growth_on_a_n': 0.822370742811481,
#  'H0': 67.36,
#  'Htime': 0.901401160072374,
#  'HubbleNow': 1.050870378305526,
#  'HubbleTimeGyr': 14.516330166270784,
#  'HubbleTimeHGyr': 9.7782,
#  'ICFormat': 'RVZel',
#  'ICPositionRange': 2000,
#  'ICVelocity2Displacement': 1.0,
#  'IOCores': 68,
#  'InitialConditionsDirectory': '/gpfs/alpine/proj-shared/ast145/AbacusSummit/AbacusSummit_base_c000_ph000/ic',
#  'InitialRedshift': 99.0,
#  'L0DensityThreshold': 99.40117835998535,
#  'L1OutputRedshifts': [8.0,
#   5.0,
#   3.0,
#   2.75,
#   2.5,
#   2.25,
#   2.0,
#   1.85,
#   1.7,
#   1.625,
#   1.55,
#   1.475,
#   1.4,
#   1.325,
#   1.25,
#   1.175,
#   1.1,
#   1.025,
#   0.95,
#   0.875,
#   0.8,
#   0.725,
#   0.65,
#   0.575,
#   0.5,
#   0.45,
#   0.4,
#   0.35,
#   0.3,
#   0.25,
#   0.2,
#   0.15,
#   0.1],
#  'LPTStepNumber': 0,
#  'LagrangianPTOrder': 2,
#  'LastHalfEtaKick': 0.0003191183410788945,
#  'LightConeDirectory': '/gpfs/alpine/proj-shared/ast145/AbacusSummit/AbacusSummit_base_c000_ph000/lightcone',
#  'LightConeOrigins': [-990.0,
#   -990.0,
#   -990.0,
#   -990.0,
#   -990.0,
#   -2990.0,
#   -990.0,
#   -2990.0,
#   -990.0],
#  'LocalWorkingDirectory': '/dev/shm/nmaksimova//AbacusSummit_base_c000_ph000',
#  'LogDirectory': '/gpfs/alpine/proj-shared/ast145/AbacusSummit/AbacusSummit_base_c000_ph000/log',
#  'LogVerbosity': 2,
#  'MachineName': 'b16n02',
#  'MicrostepTimeStep': 0,
#  'MinL1HaloNP': 35,
#  'MultipoleDirectory': '/dev/shm/nmaksimova//AbacusSummit_base_c000_ph000/multipole',
#  'MunmapThreadCore': 69,
#  'NGPUThreadCores': 2,
#  'NLightCones': 3,
#  'NP': 330225942528,
#  'N_ncdm': 1.0,
#  'N_ur': 2.0328,
#  'NearFieldRadius': 2,
#  'NodeRank': 0,
#  'NodeSize': 0,
#  'NumSlabsInsertList': 2,
#  'NumSlabsInsertListIC': 8,
#  'OMP_NUM_THREADS': 70,
#  'OMP_PLACES': '{0}:17:4,{1}:17:4,{88}:18:4,{89}:18:4',
#  'OMP_PROC_BIND': 'spread',
#  'OmegaNow_DE': 0.620112555054177,
#  'OmegaNow_K': 0.0,
#  'OmegaNow_m': 0.379887444945823,
#  'Omega_DE': 0.684808,
#  'Omega_K': 0.0,
#  'Omega_M': 0.315192,
#  'Omega_Smooth': 0.00142,
#  'Order': 8,
#  'OutputDirectory': '/gpfs/alpine/proj-shared/ast145/AbacusSummit/AbacusSummit_base_c000_ph000',
#  'OutputFormat': 'Pack9',
#  'OutputFormatVersion': 'v2.2',
#  'OutputType': 'GroupOutput',
#  'Parallel': 1,
#  'ParameterFileName': 'abacus.par',
#  'ParticleMassHMsun': 2109081520.453063,
#  'ParticleMassMsun': 3131059264.330557,
#  'ParticleSubsampleA': 0.03,
#  'ParticleSubsampleB': 0.07,
#  'Pipeline': 'singlestep',
#  'PowerSpectrumN1d': 256,
#  'PowerSpectrumStepInterval': -1,
#  'ProperSoftening': 1,
#  'RamDisk': 1,
#  'Redshift': 0.1,
#  'RunTime': 'Fri Apr 24 00:02:47 2020',
#  'SODensity': [200, 800],
#  'SODensityL1': 331.3372611999512,
#  'SODensityL2': 1325.3490447998047,
#  'SO_EvolvingThreshold': 1,
#  'SO_alpha_eligible': 0.8,
#  'ScaleFactor': 0.9090909090909092,
#  'ScaleFactorHalf': 0.9088138190720043,
#  'SimComment': 'Planck2018 LCDM',
#  'SimName': 'AbacusSummit_base_c000_ph000',
#  'SimSet': 'AbacusSummit',
#  'SiteName': 'summit',
#  'SofteningLength': 0.007233796296296301,
#  'SofteningLengthNow': 0.007962029245352342,
#  'SofteningLengthNowInternal': 0.01715952656870601,
#  'SofteningMax': 0.08680555555555561,
#  'SofteningType': 'single_spline',
#  'StateIOMode': 'overwrite',
#  'TaylorDirectory': '/dev/shm/nmaksimova//AbacusSummit_base_c000_ph000/taylor',
#  'Time': 0.857766265641474,
#  'TimeSliceRedshifts': [3.0,
#   2.5,
#   2.0,
#   1.7,
#   1.4,
#   1.1,
#   0.8,
#   0.5,
#   0.4,
#   0.3,
#   0.2,
#   0.1],
#  'TimeSliceRedshifts_Subsample': [3.0,
#   2.5,
#   2.0,
#   1.7,
#   1.4,
#   1.1,
#   0.8,
#   0.5,
#   0.4,
#   0.3,
#   0.2,
#   0.1],
#  'TimeStepAccel': 0.25,
#  'TimeStepDlna': 0.03,
#  'VelZSpace_to_Canonical': 0.86848791595498,
#  'VelZSpace_to_kms': 191067.3415100957,
#  'WorkingDirectory': '/gpfs/alpine/proj-shared/ast145/AbacusSummit/AbacusSummit_base_c000_ph000',
#  'ZD_NumBlock': 384,
#  'ZD_PLT_filename': '/ccs/home/nmaksimova/abacus/external/zeldovich-PLT/eigmodes128',
#  'ZD_PLT_target_z': 12.0,
#  'ZD_Pk_file_redshift': 1.0,
#  'ZD_Pk_filename': '/ccs/home/nmaksimova/abacus/external/AbacusSummit/Cosmologies/abacus_cosm000/CLASS_power',
#  'ZD_Pk_norm': 8.0,
#  'ZD_Pk_scale': 1.0,
#  'ZD_Pk_sigma_ratio': 0.02113950155394198,
#  'ZD_Pk_smooth': 0.0,
#  'ZD_Seed': 12321,
#  'ZD_Version': 2,
#  'ZD_f_cluster': 0.9954948095129318,
#  'ZD_k_cutoff': 1.0,
#  'ZD_mpirun_cmd': 'jsrun -n1 -cALL_CPUS -a1 -r1 -b rs',
#  'ZD_qPLT': 1,
#  'ZD_qPLT_rescale': 1,
#  'ZeldovichDirectory': '/ccs/home/nmaksimova/abacus/external/zeldovich-PLT',
#  'checkpoint_timeout': 5,
#  'etaD': -4.156711431582817,
#  'etaK': 3.141783118201425,
#  'f_growth': 0.58400728748126,
#  'fsmooth': 0.004505190487068,
#  'hMpc': 1,
#  'mpirun_cmd': 'jsrun -nALL_HOSTS -cALL_CPUS -a1 -r1 -gALL_GPUS -b none',
#  'n_s': 0.9649,
#  'omega_b': 0.02237,
#  'omega_cdm': 0.12,
#  'omega_ncdm': 0.0006442,
#  'ppd': 6912.0,
#  'step_timeout': 15,
#  'w': -1.0,
#  'w0': -1.0,
#  'wa': 0.0,
#  'cleaned_halos': True,
#  'TimeSliceRedshiftsPrev': [0.15,
#   0.2,
#   0.25,
#   0.3,
#   0.35,
#   0.4,
#   0.45,
#   0.5,
#   0.575,
#   0.65,
#   0.725,
#   0.8,
#   0.875,
#   0.95,
#   1.025,
#   1.1,
#   1.175,
#   1.25,
#   1.325,
#   1.4,
#   1.475,
#   1.55,
#   1.625,
#   1.7,
#   1.85,
#   2.0,
#   2.25,
#   2.5,
#   2.75,
#   3.0,
#   5.0],
#  'NumTimeSliceRedshiftsPrev': 31}

# %%
res[-4]
# Out:
# 1056.7109001446506

# %%
res = measure_pkl(cat.halos['x_com'], 0*uz, Lbox=Lbox, nc=256, dk=0.005)
# Out:
# /global/homes/s/sfschen/.conda/envs/nbodykit_env/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: The window argument is deprecated. Use `resampler=` instead

# %%
ch = np.loadtxt('/pscratch/sd/s/sfschen/abacus_pvs/pnms/ch/pk/AbacusSummit_base_c000_ph000_z0p100_12p75.P00')

# %%
ch.shape
# Out:
# (82, 7)

# %%
plt.plot(ch[:,0], ch[:,0] * ch[:,1])
plt.plot(res[0], res[0] * (res[1] - res[-4]))

plt.xlim(0,0.4)
# Out:
# (0.0, 0.4)

# %%
plt.plot(ch[:80,0], (ch[:,1] + res[-4])[:80] / (res[1])[:80] - 1)

plt.ylim(-0.01,0.01)
# Out:
# (-0.01, 0.01)

# %%
r.power.attrs
# Out:
# {'Nmesh': array([256, 256, 256]),
#  'BoxSize': array([2000., 2000., 2000.]),
#  'Lx': 2000.0,
#  'Ly': 2000.0,
#  'Lz': 2000.0,
#  'volume': 8000000000.0,
#  'mode': '2d',
#  'los': [0, 0, 1],
#  'Nmu': 5,
#  'poles': [0, 2, 4],
#  'dk': 0.005,
#  'kmin': 0.0,
#  'kmax': None,
#  'N1': 7570661,
#  'N2': 7570661,
#  'shotnoise': 1056.7109001446506}

# %%
r.attrs
# Out:
# {'Nmesh': array([256, 256, 256]),
#  'BoxSize': array([2000., 2000., 2000.]),
#  'Lx': 2000.0,
#  'Ly': 2000.0,
#  'Lz': 2000.0,
#  'volume': 8000000000.0,
#  'mode': '2d',
#  'los': [0, 0, 1],
#  'Nmu': 5,
#  'poles': [0, 2, 4],
#  'dk': 0.005,
#  'kmin': 0.0,
#  'kmax': None,
#  'N1': 7570661,
#  'N2': 7570661,
#  'shotnoise': 1056.7109001446506}

# %%
r.norm
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1761595/1991282475.py in <module>
# ----> 1 r.norm
#
# AttributeError: 'FFTPower' object has no attribute 'norm'

# %%
p0ks, p2ks, p4ks = [], [], []
v1ks, v3ks = [], []
s0ks, s2ks = [], []


for ii in range(25):

    print(ii)
    
    sample = f'AbacusSummit_base_c000_ph{ii:03}/halos/z{z:.3f}'
    filename = basedir + sample

    cat = CompaSOHaloCatalog(basedir+sample,fields=('x_com','v_com','N'))
    
    particle_mass = cat.header['ParticleMassHMsun'] # / (cat.header['H0']/100)
    Ms = cat.halos['N'] * particle_mass
    mass_iis = (Ms > 10.**logMmin) * (Ms < 10**logMmax)
    cat.halos = cat.halos[mass_iis]

    Lbox = cat.header['BoxSize']
    nc = 256

    OmegaM = cat.header['Omega_M']
    z = cat.header['Redshift']
    Ez = np.sqrt(OmegaM * (1+z)**3 + 1 - OmegaM)
    vfac = 0.01 * (1 + z) / Ez # convert km/s to h^{-1} Mpc, u = v / (aH) = v * (1+z) / (100 * E(z))
    uz = cat.halos['v_com'] * vfac


    res = measure_pnm(cat.halos['x_com'], uz, Lbox=Lbox, nc=nc, dk=0.005, max_order=2, redshift_space=True, los=0)

    kk, p0k, p1k, p2k, p3k, p4k = res[0]

    kk, p01_0, p01_1, p01_2, p01_3, p01_4 = res[1]

    kk, p02_0, p02_1, p02_2, p02_3, p02_4, p11_0, p11_1, p11_2, p11_3, p11_4 = res[2]

    p0ks += [p0k,]
    p2ks += [p2k,]
    p4ks += [p4k,]
    v1ks += [-2j * p01_1,]
    v3ks += [-2j * p01_3,]
    s0ks += [(2*p02_0 - 2*p11_0),]
    s2ks += [(2*p02_2 - 2*p11_2),]

# %%
res = measure_pnm(cat.halos['x_com'], uz, Lbox=Lbox, nc=512, dk=0.005, max_order=2, redshift_space=False, los=2)
# Out:
# /global/homes/s/sfschen/.conda/envs/nbodykit_env/lib/python3.7/site-packages/ipykernel_launcher.py:23: DeprecationWarning: The window argument is deprecated. Use `resampler=` instead

# %%
ch = np.loadtxt('/pscratch/sd/s/sfschen/abacus_pvs/pnms/ch/pk/AbacusSummit_base_c000_ph000_z0p100_12p75.P01')

# %%
kk, p01_0, p01_1, p01_2, p01_3, p01_4 = res[1]
#kk, p0k, p1k, p2k, p3k, p4k = res[0]

# %%
plt.plot(kk, kk**2 * p01_1)

plt.plot(ch[:,0], vfac * ch[:,0]**2 * ch[:,2])

# %%
plt.plot(kk[:80], p01_1[:80]/(vfac * ch[:80,2]) - 1)

plt.ylim(-0.004,0.004)
# Out:
# (-0.004, 0.004)

# %%
plt.plot(ch[:80,0], p0k[:80]/(ch[:80,1] +  1056.71) - 1)
plt.ylim(-0.004,0.004)
# Out:
# (-0.004, 0.004)

# %%
k = kk

p0k = np.mean(p0ks, axis=0).real
p2k = np.mean(p2ks, axis=0).real
p4k = np.mean(p4ks, axis=0).real


v1k = np.mean(v1ks, axis=0).imag
v3k = np.mean(v3ks, axis=0).imag

s0k = np.mean(s0ks, axis=0).real
s2k = np.mean(s2ks, axis=0).real

# %%
Nspec = 7
if p0ks is None:
    p0ks, p2ks, p4ks, v1ks, v3ks, s0ks, s2ks = (np.zeros_like(kk),)*Nspec

# %%
redshift_space = np.loadtxt('ch_updated/AbacusSummit_base_c000_z1.100_12.5_13.0_xins_rsd_ch.txt')
#redshift_space = np.loadtxt('pvs/AbacusSummit_base_c000_z1.100_12.5_13.0_xins_rsd.txt')


kch = redshift_space[:,0]

p0ch = redshift_space[:,1]
p2ch = redshift_space[:,2]
p4ch = redshift_space[:,3]

v1ch = redshift_space[:,4]
v3ch = redshift_space[:,5]

s0ch = redshift_space[:,6]
s2ch = redshift_space[:,7]

# %%
plt.plot(kch, p0ch/p0k - 1)

plt.plot(kch, p2ch/p2k - 1)
#plt.plot(kch, v3ch/v3k - 1)

#plt.plot(kch, -kch**2 * v3ch, 'k--')


#plt.xlim(0,0.2)
plt.ylim(-0.02, 0.02)
# Out:
# (-0.02, 0.02)

# %%
#plt.plot(kch, -kch**2 * v1ch * vfac, 'k-')
#plt.plot(kch, -kch**2 * v3ch * vfac, 'k-')

plt.plot(kch, -kch**2 * v1ch, 'k--')
plt.plot(kch, -kch**2 * v3ch, 'k--')

plt.plot(k, -k**2 * v1k)
plt.plot(k, -k**2 * v3k)

#plt.xlim(0,0.2)
#plt.ylim(-100, 2000)

# %%
plt.plot(kch, v1ch/v1k - 1)
plt.plot(kch, v3ch/v3k - 1)

plt.ylim(-0.02, 0.02)
# Out:
# (-0.02, 0.02)

# %%
plt.plot(kch, kch**3 * s0ch, 'k--')
plt.plot(kch, kch**3 * s2ch, 'k--')

plt.plot(k, k**3 * s0k, label=r'$k^3 \sigma_{s,0}$')
plt.plot(k, k**3 * s2k, label=r'$k^3 \sigma_{s,2}$')

plt.xlim(0,0.2)
#plt.ylim(-500,3000)
plt.legend()

# %%
plt.plot(kch, s0ch/s0k - 1)
plt.plot(kch, s2ch/s2k - 1)

#plt.plot(kch, -kch**2 * v3ch, 'k--')


#plt.xlim(0,0.2)
plt.ylim(-0.02, 0.02)
# Out:
# (-0.02, 0.02)

# %% [markdown]
# ## Assemble Covariance

# %%
dvecs = []

for ii in range(25):
    dvecs += [ np.concatenate((p0ks[ii].real, p2ks[ii].real, p4ks[ii].real, v1ks[ii].imag, v3ks[ii].imag, s0ks[ii].real, s2ks[ii].real)), ]

dvecs = np.array(dvecs)

# %%
cov = np.cov(dvecs.T)
sigmas = np.diag(cov)**0.5

plt.imshow(cov / sigmas[:,None] / sigmas[None,:], cmap='coolwarm')

# %%
# Clean Up
Nk = len(k)
Nspec = 7

cov_diag = np.zeros((Nspec*Nk, Nspec*Nk))

for ii in range(Nspec):

    for jj in range(Nspec):

        start_ii, start_jj = ii * Nk, jj * Nk
        
        for ind in range(Nk):

            cov_diag[start_ii + ind, start_jj + ind] = cov[start_ii + ind, start_jj + ind]

# %%
mask = (cov_diag == 0)

corr = cov_diag / sigmas[:,None] / sigmas[None,:]

plt.imshow(corr, vmin=-1, vmax=1, cmap='bwr')

plt.colorbar()
plt.show()

# %%
plt.plot(corr[20,:], label=f'$k_i = ${k[20]:.2f}')

plt.ylabel(r'$r_{ij}$')
plt.xlabel('index')
plt.legend()

# %%
r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1761595/1313387711.py in <module>
# ----> 1 r
#
# NameError: name 'r' is not defined

# %%
filebase = "pvs/"+"_".join(sample.split("_")[:3]) + '_' + sample.split("_")[-1][-6:] + '_' + f'{logMmin:.1f}' + '_' + f'{logMmax:.1f}'

# %%
np.savetxt(filebase + '_xins_rsd_periodic_los_x.txt', np.array([k,\
                                             np.mean(p0ks,axis=0).real,\
                                             np.mean(p2ks,axis=0).real,\
                                             np.mean(p4ks,axis=0).real,\
                                             np.mean(v1ks, axis=0).imag,\
                                             np.mean(v3ks, axis=0).imag,\
                                             np.mean(s0ks, axis=0).real, np.mean(s2ks, axis=0).real,\
                                                ]).T)

# %%
np.savetxt(filebase + '_xins_rsd_cov_los_x.txt', cov_diag)

# %%
plt.hist(cat.halos['x_com'][:,0], bins=30)
plt.hist(cat.halos['x_com'][:,0] + uz[:,0], bins=30)
# Out:
# (array([196034., 257123., 256824., 259946., 258782., 254550., 254750.,
#         261413., 257044., 256031., 255567., 263467., 262688., 251389.,
#         246587., 257778., 258248., 258698., 254745., 259242., 253502.,
#         255643., 258297., 257620., 256256., 260384., 259076., 254725.,
#         253439., 186132.]),
#  array([-1014.8964   ,  -947.11053  ,  -879.32465  ,  -811.5388   ,
#          -743.7529   ,  -675.96704  ,  -608.18115  ,  -540.39526  ,
#          -472.6094   ,  -404.82352  ,  -337.03763  ,  -269.25177  ,
#          -201.46588  ,  -133.68001  ,   -65.89413  ,     1.8917542,
#            69.677635 ,   137.46352  ,   205.24939  ,   273.03528  ,
#           340.82114  ,   408.60703  ,   476.3929   ,   544.1788   ,
#           611.96466  ,   679.75055  ,   747.53644  ,   815.32227  ,
#           883.10815  ,   950.89404  ,  1018.67993  ], dtype=float32),
#  <BarContainer object of 30 artists>)

# %%
np.sum(np.abs(cat.halos['x_com'][:,0]) > 1000)
# Out:
# 0

# %%
np.sum(np.abs(cat.halos['x_com'][:,2] + uz[:,2]) > 1000)
# Out:
# 9498

# %%
cat.halos['x_com'].shape
# Out:
# (7575980, 3)

# %%
9500/7575980
# Out:
# 0.0012539631836409283
