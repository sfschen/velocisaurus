# %%
# %matplotlib inline
import sys, os
os.environ['COBAYA_NOMPI'] = 'True'

import numpy as np
import matplotlib.pyplot as plt
from cobaya.model import get_model
from cobaya.yaml import yaml_load
import yaml
from yaml import Loader

import os

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

saved_backend = plt.rcParams["backend"]

from cobaya.yaml          import yaml_load_file
from cobaya.samplers.mcmc import plot_progress
from cobaya.model         import get_model
from cobaya.run import run

#
from getdist.mcsamples    import MCSamplesFromCobaya
from getdist.mcsamples    import loadMCSamples
import getdist.plots      as     gdplt
#
matplotlib.use(saved_backend)

sys.path.append('/global/homes/s/sfschen/velocileptors/') #change this to point to your cobaya_wl_x_rsd repo
sys.path.append('velocity_eft/likelihood')
sys.path.append('velocity_eft/')

# %%
#plt.rcParams['figure.figsize']        = 8., 6.
#plt.rcParams['figure.dpi']            = 100
#plt.rcParams['figure.subplot.left']   = 0.125
#plt.rcParams['figure.subplot.right']  = 0.9
#plt.rcParams['figure.subplot.bottom'] = 0.125
#plt.rcParams['figure.subplot.top']    = 0.9
#plt.rcParams['axes.labelsize']        = 16
#plt.rcParams['axes.titlesize']        = 16
#plt.rcParams['xtick.top']             = True
#plt.rcParams['xtick.bottom']          = True

#plt.rcParams['ytick.left']            = True
#plt.rcParams['ytick.right']           = True
#plt.rcParams['xtick.direction']       = 'in'
#plt.rcParams['ytick.direction']       = 'in'
#plt.rcParams['xtick.labelsize']       = 16
#plt.rcParams['ytick.labelsize']       = 16
#plt.rcParams['xtick.major.pad']       = 6.
#plt.rcParams['xtick.minor.pad']       = 6.
#plt.rcParams['ytick.major.pad']       = 6.
#plt.rcParams['ytick.minor.pad']       = 6.
#plt.rcParams['xtick.major.size']      = 6. # major tick size in points
#plt.rcParams['xtick.minor.size']      = 3. # minor tick size in points
#plt.rcParams['ytick.major.size']      = 6. # major tick size in points
#plt.rcParams['ytick.minor.size']      = 3. # minor tick size in points
#plt.rcParams['text.usetex']           = True
#plt.rcParams['font.family']           = 'serif'
plt.rcParams['font.size']             = 16

# %%
info_txt = 'velocity_eft/likelihood/paper_yamls/fit_fz_ept_am_binned_z_0.1_logM_12.5_13.0.yaml'

print(info_txt)

with open(info_txt, 'rb') as fp:
    info = yaml.load(fp, Loader=Loader)
# Out:
# velocity_eft/likelihood/paper_yamls/fit_fz_ept_am_binned_z_0.1_logM_12.5_13.0.yaml

# %%
info
# Out:
# {'theory': {'pairwise_velocity_likelihood_am_binned.PT_Theory': {'plinfn': '/pscratch/sd/s/sfschen/abacus_pvs/plins/abacus_plin_bspline.txt',
#    'pnwfn': '/pscratch/sd/s/sfschen/abacus_pvs/plins/abacus_pnw_bspline.txt',
#    'Dz': 0.9483464322302488,
#    'kmax': 0.4,
#    'kmin': 0.001,
#    'nk': 400}},
#  'likelihood': {'pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood': {'kdatfn': '/pscratch/sd/s/sfschen/abacus_pvs/kbins_nc_256_Lbox_2000_dk_0.005.txt',
#    'datfn': '/pscratch/sd/s/sfschen/abacus_pvs/pvs/AbacusSummit_base_c000_z0.100_12.5_13.0_xins_rsd_periodic_los_x.txt',
#    'covfn': '/pscratch/sd/s/sfschen/abacus_pvs/pvs/AbacusSummit_base_c000_z0.100_12.5_13.0_xins_rsd_cov_gp.txt',
#    'diagonal_covariance': False,
#    'linear_param_dict_fn': '/pscratch/sd/s/sfschen/abacus_pvs/velocity_eft/likelihood/paper_yamls/linear_params_z_0.1_logM_12.5_13.0.yaml',
#    'include_priors': True,
#    'optimize': False,
#    'kmin': 0.04,
#    'p0max': 0.15,
#    'p2max': 0.125,
#    'p4max': 0.0,
#    'v1max': 0.15,
#    'v3max': 0.0,
#    's0max': 0.15,
#    's2max': 0.125}},
#  'params': {'fz': {'prior': {'dist': 'uniform', 'min': 0.0, 'max': 5.0},
#    'ref': {'dist': 'norm', 'loc': 0.584, 'scale': 0.01},
#    'latex': 'f(z)'},
#   'b1': {'prior': {'dist': 'uniform', 'min': 0.0, 'max': 5.0},
#    'ref': {'dist': 'norm', 'loc': 1.05, 'scale': 0.05},
#    'latex': 'b_1'},
#   'b2': {'prior': {'dist': 'norm', 'loc': 0.0, 'scale': 10.0},
#    'ref': {'dist': 'norm', 'loc': -1.64, 'scale': 1.0},
#    'latex': 'b_2'},
#   'bs': {'prior': {'dist': 'norm', 'loc': 0.0, 'scale': 5.0},
#    'ref': {'dist': 'norm', 'loc': 0.586, 'scale': 1.0},
#    'latex': 'b_s'},
#   'nonmarg_chi2': {'latex': '\\chi^2_{nonmarg}'}},
#  'sampler': {'mcmc': {'learn_proposal': True,
#    'learn_proposal_Rminus1_max': 10.0,
#    'learn_proposal_Rminus1_max_early': 10.0,
#    'output_every': '60s',
#    'measure_speeds': False,
#    'max_tries': 10000,
#    'drag': False,
#    'oversample_power': 0.4,
#    'proposal_scale': 1.5,
#    'Rminus1_stop': 0.05}},
#  'output': 'chains/fit_fz_ept_am_binned_z_0.1_logM_12.5_13.0',
#  'timing': True,
#  'stop_on_error': True}

# %%
updated_info, sampler = run(info)
# Out:
# [output] Output to be read-from/written-into folder 'chains', with prefix 'fit_fz_ept_am_binned_z_0.1_logM_12.5_13.0'
# [mcmc] Getting initial point... (this may take a few seconds)
# [mcmc] Initial point: fz:0.5559982, b1:1.065275, b2:-2.354165, bs:2.669956
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 10 (would be 10 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2025-07-28 12:53:01 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00519233 s (511 evaluations, 2.65328 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00835869 s (129 evaluations, 1.07827 s total)
# [mcmc]  - Acceptance rate: 0.313
# [mcmc]  - Convergence of means: R-1 = 0.438571 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00608498 s (859 evaluations, 5.227 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00967005 s (215 evaluations, 2.07906 s total)
# [mcmc]  - Acceptance rate: 0.390
# [mcmc]  - Convergence of means: R-1 = 0.803667 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00613512 s (1219 evaluations, 7.47871 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00976531 s (305 evaluations, 2.97842 s total)
# [mcmc]  - Acceptance rate: 0.411
# [mcmc]  - Convergence of means: R-1 = 0.220560 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00583934 s (1688 evaluations, 9.85681 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00922874 s (423 evaluations, 3.90376 s total)
# [mcmc]  - Acceptance rate: 0.397
# [mcmc]  - Convergence of means: R-1 = 0.087483 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.0062439 s (2195 evaluations, 13.7054 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00978401 s (549 evaluations, 5.37142 s total)
# [mcmc]  - Acceptance rate: 0.380
# [mcmc]  - Convergence of means: R-1 = 0.212389 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00649355 s (2715 evaluations, 17.63 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.010121 s (680 evaluations, 6.88229 s total)
# [mcmc]  - Acceptance rate: 0.360
# [mcmc]  - Convergence of means: R-1 = 0.156702 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00670821 s (3222 evaluations, 21.6139 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0105655 s (807 evaluations, 8.52639 s total)
# [mcmc]  - Acceptance rate: 0.349
# [mcmc]  - Convergence of means: R-1 = 0.236964 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00657199 s (3786 evaluations, 24.8816 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0104105 s (947 evaluations, 9.85871 s total)
# [mcmc]  - Acceptance rate: 0.334
# [mcmc]  - Convergence of means: R-1 = 0.218177 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00645284 s (4220 evaluations, 27.231 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.010246 s (1056 evaluations, 10.8197 s total)
# [mcmc]  - Acceptance rate: 0.337
# [mcmc]  - Convergence of means: R-1 = 0.142193 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00638893 s (4669 evaluations, 29.8299 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0102184 s (1169 evaluations, 11.9453 s total)
# [mcmc]  - Acceptance rate: 0.336
# [mcmc]  - Convergence of means: R-1 = 0.102364 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00627767 s (5254 evaluations, 32.9829 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0100093 s (1315 evaluations, 13.1622 s total)
# [mcmc]  - Acceptance rate: 0.325
# [mcmc]  - Convergence of means: R-1 = 0.114110 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00618128 s (5817 evaluations, 35.9565 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00986072 s (1455 evaluations, 14.3474 s total)
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.157965 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00612865 s (6340 evaluations, 38.8556 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00979785 s (1586 evaluations, 15.5394 s total)
# [mcmc]  - Acceptance rate: 0.316
# [mcmc]  - Convergence of means: R-1 = 0.052758 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2025-07-28 12:54:01 : 6857 steps taken, and 2227 accepted.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00609787 s (6927 evaluations, 42.24 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00980831 s (1733 evaluations, 16.9978 s total)
# [mcmc]  - Acceptance rate: 0.310
# [mcmc]  - Convergence of means: R-1 = 0.041006 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00611786 s (7412 evaluations, 45.3455 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0099405 s (1854 evaluations, 18.4297 s total)
# [mcmc]  - Acceptance rate: 0.310
# [mcmc]  - Convergence of means: R-1 = 0.075531 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2560 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00609338 s (7872 evaluations, 47.9671 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0099104 s (1969 evaluations, 19.5136 s total)
# [mcmc]  - Acceptance rate: 0.311
# [mcmc]  - Convergence of means: R-1 = 0.074138 after 2048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2720 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00605409 s (8344 evaluations, 50.5153 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00983463 s (2087 evaluations, 20.5249 s total)
# [mcmc]  - Acceptance rate: 0.313
# [mcmc]  - Convergence of means: R-1 = 0.058154 after 2176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00600599 s (8930 evaluations, 53.6335 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00974439 s (2234 evaluations, 21.769 s total)
# [mcmc]  - Acceptance rate: 0.309
# [mcmc]  - Convergence of means: R-1 = 0.139125 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3040 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00600502 s (9508 evaluations, 57.0957 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00976617 s (2378 evaluations, 23.2239 s total)
# [mcmc]  - Acceptance rate: 0.306
# [mcmc]  - Convergence of means: R-1 = 0.176772 after 2432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3200 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00598612 s (10075 evaluations, 60.3101 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00973234 s (2519 evaluations, 24.5158 s total)
# [mcmc]  - Acceptance rate: 0.305
# [mcmc]  - Convergence of means: R-1 = 0.140413 after 2560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00595095 s (10572 evaluations, 62.9134 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00965696 s (2644 evaluations, 25.533 s total)
# [mcmc]  - Acceptance rate: 0.306
# [mcmc]  - Convergence of means: R-1 = 0.110370 after 2688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3520 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00596119 s (11087 evaluations, 66.0917 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00975059 s (2773 evaluations, 27.0384 s total)
# [mcmc]  - Acceptance rate: 0.306
# [mcmc]  - Convergence of means: R-1 = 0.056488 after 2816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3680 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.0059492 s (11683 evaluations, 69.5045 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00975699 s (2922 evaluations, 28.5099 s total)
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.044338 after 2944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3840 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00592589 s (12376 evaluations, 73.3388 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00972043 s (3095 evaluations, 30.0847 s total)
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.089494 after 3072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4000 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00589693 s (12936 evaluations, 76.2827 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0096684 s (3235 evaluations, 31.2773 s total)
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.114630 after 3200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4160 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00590096 s (13487 evaluations, 79.5863 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00969516 s (3373 evaluations, 32.7018 s total)
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.086945 after 3328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2025-07-28 12:55:01 : 14103 steps taken, and 4301 accepted.
# [mcmc] Learn + convergence test @ 4320 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00588064 s (14153 evaluations, 83.2288 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00967636 s (3540 evaluations, 34.2543 s total)
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.076128 after 3456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4480 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00587083 s (14632 evaluations, 85.902 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00966571 s (3659 evaluations, 35.3668 s total)
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.060484 after 3584 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4640 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00586799 s (15246 evaluations, 89.4633 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00968761 s (3812 evaluations, 36.9292 s total)
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.032063 after 3712 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4800 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00584702 s (15861 evaluations, 92.7396 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00964626 s (3967 evaluations, 38.2667 s total)
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.037516 after 3840 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.102779 after 4800 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 4800 accepted steps.
# [pairwise_velocity_likelihood_am_binned.pairwisevelocitylikelihood] Average evaluation time for pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood: 0.00584702 s  (15861 evaluations)
# [pairwise_velocity_likelihood_am_binned.pt_theory] Average evaluation time for pairwise_velocity_likelihood_am_binned.PT_Theory: 0.00964626 s  (3967 evaluations)

# %%
info_txt = 'velocity_eft/likelihood/paper_yamls/fit_fz_ept_am_binned_z_0.1_logM_12.5_13.0_p02v1.yaml'

print(info_txt)

with open(info_txt, 'rb') as fp:
    info_pv= yaml.load(fp, Loader=Loader)
# Out:
# velocity_eft/likelihood/paper_yamls/fit_fz_ept_am_binned_z_0.1_logM_12.5_13.0_p02v1.yaml

# %%
info_txt = 'velocity_eft/likelihood/paper_yamls/fit_fz_ept_am_binned_z_0.1_logM_12.5_13.0_p02.yaml'

print(info_txt)

with open(info_txt, 'rb') as fp:
    info_p= yaml.load(fp, Loader=Loader)
# Out:
# velocity_eft/likelihood/paper_yamls/fit_fz_ept_am_binned_z_0.1_logM_12.5_13.0_p02.yaml

# %%
#info_pv0p15

# %%
updated_info, sampler = run(info_pv)
# Out:
# [output] Output to be read-from/written-into folder 'chains', with prefix 'fit_fz_ept_am_binned_z_0.1_logM_12.5_13.0_p02v1'
# [mcmc] Getting initial point... (this may take a few seconds)
# [mcmc] Initial point: fz:0.5930586, b1:1.006629, b2:-1.581672, bs:0.1176727
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 10 (would be 10 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2025-07-28 12:55:48 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00584047 s (437 evaluations, 2.55228 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00924691 s (111 evaluations, 1.02641 s total)
# [mcmc]  - Acceptance rate: 0.365
# [mcmc]  - Convergence of means: R-1 = 2.058254 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00594143 s (787 evaluations, 4.6759 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00929269 s (197 evaluations, 1.83066 s total)
# [mcmc]  - Acceptance rate: 0.403
# [mcmc]  - Convergence of means: R-1 = 1.690125 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00589724 s (1301 evaluations, 7.67231 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00921377 s (327 evaluations, 3.0129 s total)
# [mcmc]  - Acceptance rate: 0.355
# [mcmc]  - Convergence of means: R-1 = 0.646444 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00577102 s (1770 evaluations, 10.2147 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00926909 s (443 evaluations, 4.10621 s total)
# [mcmc]  - Acceptance rate: 0.357
# [mcmc]  - Convergence of means: R-1 = 0.427256 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00592289 s (2273 evaluations, 13.4627 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0094247 s (569 evaluations, 5.36265 s total)
# [mcmc]  - Acceptance rate: 0.349
# [mcmc]  - Convergence of means: R-1 = 0.195730 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00576882 s (2830 evaluations, 16.3258 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00916778 s (708 evaluations, 6.49079 s total)
# [mcmc]  - Acceptance rate: 0.330
# [mcmc]  - Convergence of means: R-1 = 0.178613 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00582591 s (3466 evaluations, 20.1926 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0092257 s (867 evaluations, 7.99868 s total)
# [mcmc]  - Acceptance rate: 0.310
# [mcmc]  - Convergence of means: R-1 = 0.227144 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.0061705 s (4215 evaluations, 26.0086 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00981204 s (1055 evaluations, 10.3517 s total)
# [mcmc]  - Acceptance rate: 0.286
# [mcmc]  - Convergence of means: R-1 = 0.468527 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00612486 s (4848 evaluations, 29.6933 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00968729 s (1213 evaluations, 11.7507 s total)
# [mcmc]  - Acceptance rate: 0.279
# [mcmc]  - Convergence of means: R-1 = 0.199122 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00627884 s (5471 evaluations, 34.3515 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00992309 s (1369 evaluations, 13.5847 s total)
# [mcmc]  - Acceptance rate: 0.273
# [mcmc]  - Convergence of means: R-1 = 0.339750 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00639778 s (5975 evaluations, 38.2268 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0101056 s (1495 evaluations, 15.1079 s total)
# [mcmc]  - Acceptance rate: 0.276
# [mcmc]  - Convergence of means: R-1 = 0.256107 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2025-07-28 12:56:48 : 6643 steps taken, and 1896 accepted.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00628427 s (6857 evaluations, 43.0912 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00995763 s (1716 evaluations, 17.0873 s total)
# [mcmc]  - Acceptance rate: 0.264
# [mcmc]  - Convergence of means: R-1 = 0.128205 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00619043 s (7472 evaluations, 46.2549 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00982793 s (1869 evaluations, 18.3684 s total)
# [mcmc]  - Acceptance rate: 0.262
# [mcmc]  - Convergence of means: R-1 = 0.103575 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00617734 s (8043 evaluations, 49.6843 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00979047 s (2012 evaluations, 19.6984 s total)
# [mcmc]  - Acceptance rate: 0.262
# [mcmc]  - Convergence of means: R-1 = 0.160894 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00616462 s (8683 evaluations, 53.5274 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00976874 s (2172 evaluations, 21.2177 s total)
# [mcmc]  - Acceptance rate: 0.260
# [mcmc]  - Convergence of means: R-1 = 0.224726 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2560 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00615327 s (9321 evaluations, 57.3546 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00973717 s (2331 evaluations, 22.6974 s total)
# [mcmc]  - Acceptance rate: 0.258
# [mcmc]  - Convergence of means: R-1 = 0.234290 after 2048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2720 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00608545 s (10003 evaluations, 60.8727 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00963963 s (2502 evaluations, 24.1184 s total)
# [mcmc]  - Acceptance rate: 0.256
# [mcmc]  - Convergence of means: R-1 = 0.149705 after 2176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00602523 s (10652 evaluations, 64.1808 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00954135 s (2664 evaluations, 25.4182 s total)
# [mcmc]  - Acceptance rate: 0.254
# [mcmc]  - Convergence of means: R-1 = 0.108830 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3040 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00599635 s (11435 evaluations, 68.5682 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00947777 s (2860 evaluations, 27.1064 s total)
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.062652 after 2432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3200 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00600733 s (12115 evaluations, 72.7788 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00947769 s (3030 evaluations, 28.7174 s total)
# [mcmc]  - Acceptance rate: 0.247
# [mcmc]  - Convergence of means: R-1 = 0.054050 after 2560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00598616 s (13046 evaluations, 78.0955 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00944584 s (3263 evaluations, 30.8218 s total)
# [mcmc]  - Acceptance rate: 0.240
# [mcmc]  - Convergence of means: R-1 = 0.090917 after 2688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3520 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00597687 s (13782 evaluations, 82.3732 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0094218 s (3447 evaluations, 32.4769 s total)
# [mcmc]  - Acceptance rate: 0.238
# [mcmc]  - Convergence of means: R-1 = 0.078522 after 2816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2025-07-28 12:57:48 : 14100 steps taken, and 3575 accepted.
# [mcmc] Learn + convergence test @ 3680 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.0059969 s (14492 evaluations, 86.9071 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00943022 s (3624 evaluations, 34.1751 s total)
# [mcmc]  - Acceptance rate: 0.237
# [mcmc]  - Convergence of means: R-1 = 0.077244 after 2944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3840 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00601895 s (15290 evaluations, 92.0298 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00947158 s (3824 evaluations, 36.2193 s total)
# [mcmc]  - Acceptance rate: 0.235
# [mcmc]  - Convergence of means: R-1 = 0.074710 after 3072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4000 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00604998 s (15978 evaluations, 96.6666 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00951312 s (3995 evaluations, 38.0049 s total)
# [mcmc]  - Acceptance rate: 0.233
# [mcmc]  - Convergence of means: R-1 = 0.060946 after 3200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4160 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00602768 s (16917 evaluations, 101.97 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00948015 s (4230 evaluations, 40.1011 s total)
# [mcmc]  - Acceptance rate: 0.229
# [mcmc]  - Convergence of means: R-1 = 0.056431 after 3328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4320 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.006007 s (17491 evaluations, 105.069 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00944926 s (4374 evaluations, 41.3311 s total)
# [mcmc]  - Acceptance rate: 0.231
# [mcmc]  - Convergence of means: R-1 = 0.068571 after 3456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4480 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00609161 s (18251 evaluations, 111.178 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00957713 s (4564 evaluations, 43.71 s total)
# [mcmc]  - Acceptance rate: 0.229
# [mcmc]  - Convergence of means: R-1 = 0.044777 after 3584 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4640 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00610668 s (18940 evaluations, 115.661 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00958729 s (4736 evaluations, 45.4054 s total)
# [mcmc]  - Acceptance rate: 0.229
# [mcmc]  - Convergence of means: R-1 = 0.025375 after 3712 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.165726 after 4640 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 4640 accepted steps.
# [pairwise_velocity_likelihood_am_binned.pairwisevelocitylikelihood] Average evaluation time for pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood: 0.00610668 s  (18940 evaluations)
# [pairwise_velocity_likelihood_am_binned.pt_theory] Average evaluation time for pairwise_velocity_likelihood_am_binned.PT_Theory: 0.00958729 s  (4736 evaluations)

# %%
updated_info, sampler = run(info_p)
# Out:
# [output] Output to be read-from/written-into folder 'chains', with prefix 'fit_fz_ept_am_binned_z_0.1_logM_12.5_13.0_p02'
# [mcmc] Getting initial point... (this may take a few seconds)
# [mcmc] Initial point: fz:0.5814381, b1:1.109782, b2:-2.188931, bs:1.186164
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 10 (would be 10 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2025-07-28 12:58:43 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00598134 s (319 evaluations, 1.90805 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00981017 s (81 evaluations, 0.794624 s total)
# [mcmc]  - Acceptance rate: 0.516
# [mcmc]  - Convergence of means: R-1 = 2.031640 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00620342 s (611 evaluations, 3.79029 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00999414 s (154 evaluations, 1.5391 s total)
# [mcmc]  - Acceptance rate: 0.528
# [mcmc]  - Convergence of means: R-1 = 1.058057 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00625744 s (1053 evaluations, 6.58908 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0100507 s (264 evaluations, 2.65339 s total)
# [mcmc]  - Acceptance rate: 0.445
# [mcmc]  - Convergence of means: R-1 = 1.825653 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00613473 s (1566 evaluations, 9.60698 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00979287 s (392 evaluations, 3.83881 s total)
# [mcmc]  - Acceptance rate: 0.393
# [mcmc]  - Convergence of means: R-1 = 0.824889 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00630004 s (2004 evaluations, 12.6253 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0100183 s (502 evaluations, 5.02917 s total)
# [mcmc]  - Acceptance rate: 0.380
# [mcmc]  - Convergence of means: R-1 = 0.213803 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00602812 s (2549 evaluations, 15.3657 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00962124 s (638 evaluations, 6.13835 s total)
# [mcmc]  - Acceptance rate: 0.353
# [mcmc]  - Convergence of means: R-1 = 0.281304 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00635955 s (3132 evaluations, 19.9181 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0100652 s (784 evaluations, 7.89111 s total)
# [mcmc]  - Acceptance rate: 0.330
# [mcmc]  - Convergence of means: R-1 = 0.126107 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00634073 s (3654 evaluations, 23.169 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0100571 s (915 evaluations, 9.20229 s total)
# [mcmc]  - Acceptance rate: 0.323
# [mcmc]  - Convergence of means: R-1 = 0.175683 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00635213 s (4171 evaluations, 26.4947 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0101141 s (1044 evaluations, 10.5592 s total)
# [mcmc]  - Acceptance rate: 0.318
# [mcmc]  - Convergence of means: R-1 = 0.298095 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00618861 s (4792 evaluations, 29.6558 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00988651 s (1199 evaluations, 11.8539 s total)
# [mcmc]  - Acceptance rate: 0.306
# [mcmc]  - Convergence of means: R-1 = 0.064820 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00607436 s (5378 evaluations, 32.6679 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00971758 s (1345 evaluations, 13.0701 s total)
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.193782 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.0059974 s (5820 evaluations, 34.9049 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00959796 s (1456 evaluations, 13.9746 s total)
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.081990 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.005929 s (6305 evaluations, 37.3824 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0094729 s (1577 evaluations, 14.9388 s total)
# [mcmc]  - Acceptance rate: 0.305
# [mcmc]  - Convergence of means: R-1 = 0.062613 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00599982 s (6861 evaluations, 41.1648 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00955968 s (1717 evaluations, 16.414 s total)
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.071811 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2025-07-28 12:59:43 : 7006 steps taken, and 2293 accepted.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00592957 s (7395 evaluations, 43.8492 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00944449 s (1850 evaluations, 17.4723 s total)
# [mcmc]  - Acceptance rate: 0.303
# [mcmc]  - Convergence of means: R-1 = 0.063761 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2560 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00586218 s (8035 evaluations, 47.1026 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00932469 s (2009 evaluations, 18.7333 s total)
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.094836 after 2048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2720 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00583561 s (8535 evaluations, 49.8069 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00927313 s (2135 evaluations, 19.7981 s total)
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.115033 after 2176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00586648 s (9110 evaluations, 53.4436 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00930808 s (2278 evaluations, 21.2038 s total)
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.102994 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3040 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00589631 s (9702 evaluations, 57.206 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.0093537 s (2427 evaluations, 22.7014 s total)
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.047849 after 2432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3200 samples accepted.
# [likelihoodcollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood : 0.00589815 s (10259 evaluations, 60.5091 s total)
# [theorycollection] Average computation time:
#    pairwise_velocity_likelihood_am_binned.PT_Theory : 0.00935082 s (2566 evaluations, 23.9942 s total)
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.031356 after 2560 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.189401 after 3200 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 3200 accepted steps.
# [pairwise_velocity_likelihood_am_binned.pairwisevelocitylikelihood] Average evaluation time for pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood: 0.00589815 s  (10259 evaluations)
# [pairwise_velocity_likelihood_am_binned.pt_theory] Average evaluation time for pairwise_velocity_likelihood_am_binned.PT_Theory: 0.00935082 s  (2566 evaluations)

# %%
samples = loadMCSamples(os.path.abspath(info["output"]),\
                        settings={'ignore_rows':0.3}, no_cache=True)

samples_pv = loadMCSamples(os.path.abspath(info_pv["output"]),\
                        settings={'ignore_rows':0.3}, no_cache=True)

samples_p = loadMCSamples(os.path.abspath(info_p["output"]),\
                        settings={'ignore_rows':0.3}, no_cache=True)
# Out:
# [root] *WARNING* outlier fraction 0.0026785714285714286
# [root] *WARNING* outlier fraction 0.00646551724137931
# [root] *WARNING* outlier fraction 0.019642857142857142

# %%
samples.getLatex()
# Out:
# (['f(z)',
#   'b_1',
#   'b_2',
#   'b_s',
#   '\\chi^2_{nonmarg}',
#   '-\\log\\pi',
#   '-\\log\\pi_\\mathrm{0}',
#   '\\chi^2',
#   '\\chi^2_\\mathrm{pairwise\\ velocity\\ likelihood\\ am\\ binned.PairwiseVelocityLikelihood}'],
#  ['0.5842\\pm 0.0076',
#   '1.078^{+0.020}_{-0.016}',
#   '-0.36\\pm 0.47',
#   '0.21^{+0.51}_{-0.61}',
#   '11.4^{+1.1}_{-3.2}',
#   '8.97741^{+0.00064}_{-0.0088}',
#   '8.97741^{+0.00064}_{-0.0088}',
#   '-94.9\\pm 2.9',
#   '-94.9\\pm 2.9'])

# %%
samples_pv.getLatex()
# Out:
# (['f(z)',
#   'b_1',
#   'b_2',
#   'b_s',
#   '\\chi^2_{nonmarg}',
#   '-\\log\\pi',
#   '-\\log\\pi_\\mathrm{0}',
#   '\\chi^2',
#   '\\chi^2_\\mathrm{pairwise\\ velocity\\ likelihood\\ am\\ binned.PairwiseVelocityLikelihood}'],
#  ['0.5871^{+0.0099}_{-0.012}',
#   '1.073^{+0.031}_{-0.021}',
#   '-0.64\\pm 0.70',
#   '0.54\\pm 0.82',
#   '6.61^{+0.86}_{-2.5}',
#   '8.9924^{+0.0042}_{-0.024}',
#   '8.9924^{+0.0042}_{-0.024}',
#   '-135.8\\pm 2.2',
#   '-135.8\\pm 2.2'])

# %%
samples_p.getLatex()
# Out:
# (['f(z)',
#   'b_1',
#   'b_2',
#   'b_s',
#   '\\chi^2_{nonmarg}',
#   '-\\log\\pi',
#   '-\\log\\pi_\\mathrm{0}',
#   '\\chi^2',
#   '\\chi^2_\\mathrm{pairwise\\ velocity\\ likelihood\\ am\\ binned.PairwiseVelocityLikelihood}'],
#  ['0.597^{+0.036}_{-0.041}',
#   '1.061^{+0.043}_{-0.027}',
#   '-0.94\\pm 0.94',
#   '0.86\\pm 0.98',
#   '4.35^{+0.87}_{-2.9}',
#   '9.0113^{+0.0055}_{-0.044}',
#   '9.0113^{+0.0055}_{-0.044}',
#   '-156.6\\pm 2.6',
#   '-156.6\\pm 2.6'])

# %%
0.0385/0.0076
# Out:
# 5.065789473684211

# %%
0.0076/0.584
# Out:
# 0.013013698630136987

# %%
gdplot = gdplt.get_subplot_plotter(width_inch=8)

# %%
gdplot.triangle_plot([samples, samples_pv, samples_p],\
                     ['fz','b1','b2','bs'],\
                     filled=True,
                     title_limit=0,contour_lws=2,\
                     markers={'fz':0.584})

# %%
gdplot = gdplt.get_subplot_plotter(width_inch=8,)

gdplot.triangle_plot([samples_p, samples_pv, samples,],\
                     ['fz','b1','b2','bs'],\
                     filled=True,
                     title_limit=0,contour_lws=2,\
                     legend_labels=[r'$P_{0,2}$', r'$P_{0,2} + v_1$', r'$P_{0,2} + v_1 + \sigma^2_{0,2}$'],\
                     legend_loc='upper right',\
                     markers={'fz':0.584})


gdplot.fig.text(0.6, 0.93, r'$k_{max} = 0.15\ h \text{Mpc}^{-1}$', ha='center', fontsize=12)
gdplot.fig.text(0.6, 0.90, r'$(z, M_{min}, M_{max}) = (0.1, 12.5, 13.0)$', ha='center', fontsize=12)


#plt.suptitle(r'$k_{max} = 0.15\ h \text{Mpc}^{-1}, \quad (z, M_{min}, M_{max}) = (0.1, 12.5, 13.0)$',fontsize=12,va='bottom');

gdplot.fig.set_tight_layout(True)

plt.savefig('Figures/fz_fit_z_0.1.pdf')
# Out:
# /tmp/ipykernel_1839812/1002992510.py:20: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig('Figures/fz_fit_z_0.1.pdf')
# /tmp/ipykernel_1839812/1002992510.py:20: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig('Figures/fz_fit_z_0.1.pdf')
# /global/homes/s/sfschen/.conda/envs/pcobaya/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
samples_p.paramNames.parWithName('b1').label = 'c_{\delta}'
samples_p.paramNames.parWithName('b2').label = 'c_{\delta^2}'
samples_p.paramNames.parWithName('bs').label = 'c_{s^2}'

samples_pv.paramNames.parWithName('b1').label = 'c_{\delta}'
samples_pv.paramNames.parWithName('b2').label = 'c_{\delta^2}'
samples_pv.paramNames.parWithName('bs').label = 'c_{s^2}'

samples.paramNames.parWithName('b1').label = 'c_{\delta}'
samples.paramNames.parWithName('b2').label = 'c_{\delta^2}'
samples.paramNames.parWithName('bs').label = 'c_{s^2}'

# %%
gdplot = gdplt.get_subplot_plotter(width_inch=8,)

gdplot.triangle_plot([samples_p, samples_pv, samples,],\
                     ['fz','b1','b2','bs'],\
                     filled=True,
                     title_limit=0,contour_lws=2,\
                     legend_labels=[r'$P_{0,2}$', r'$P_{0,2} + v_1$', r'$P_{0,2} + v_1 + \sigma^2_{0,2}$'],\
                     legend_loc='upper right',\
                     param_limits={'fz':(0.55,0.63)},\
                     markers={'fz':0.584})


gdplot.fig.text(0.6, 0.93, r'$k_{max} = 0.15\ h \text{Mpc}^{-1}$', ha='center', fontsize=12)
gdplot.fig.text(0.6, 0.90, r'$(z, M_{min}, M_{max}) = (0.1, 12.5, 13.0)$', ha='center', fontsize=12)


#plt.suptitle(r'$k_{max} = 0.15\ h \text{Mpc}^{-1}, \quad (z, M_{min}, M_{max}) = (0.1, 12.5, 13.0)$',fontsize=12,va='bottom');

gdplot.fig.set_tight_layout(True)

plt.savefig('Figures/fz_fit_z_0.1_narrow.pdf')
# Out:
# /tmp/ipykernel_1839812/2614508046.py:21: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig('Figures/fz_fit_z_0.1_narrow.pdf')
# /tmp/ipykernel_1839812/2614508046.py:21: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig('Figures/fz_fit_z_0.1_narrow.pdf')
# /global/homes/s/sfschen/.conda/envs/pcobaya/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
gdplot.triangle_plot([samples_p, samples_pv, samples,],\
                     ['fz','b1'],\
                     filled=True,
                     title_limit=0,contour_lws=2,\
                     legend_labels=[r'$P_{0,2}$', r'$P_{0,2} + v_1$', r'$P_{0,2} + v_1 + \sigma^2_{0,2}$'],\
                     legend_loc='upper right',\
                     markers={'fz':0.584})

plt.suptitle(r'$k_{max} = 0.15\ h \text{Mpc}^{-1}, \quad (z, M_{min}, M_{max}) = (0.1, 12.5, 13.0)$',fontsize=12,va='bottom');

# %%
model = get_model(info)
# Out:
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output', 'stop_on_error']

# %%
p = samples.getParams()

ii = np.argmin(p.nonmarg_chi2)

print(p.nonmarg_chi2[ii])

bf_params = {}

for pname in model.prior.params:
    bf_params[pname] = getattr(p, pname)[ii]
# Out:
# 7.3186694

# %%
model.logposterior(bf_params)
# Out:
# LogPosterior(logpost=40.43464631067391, logpriors=[-8.970255626773975], loglikes=array([49.40490194]), derived=[7.31866951637403], finite=False)

# %%
like = model.likelihood['pairwise_velocity_likelihood_am_binned.PairwiseVelocityLikelihood']

# %%
kdat = like.kdat
p0dat = like.p0dat
p2dat = like.p2dat
p4dat = like.p4dat

v1dat = like.v1dat
v3dat = like.v3dat

s0dat = like.s0dat
s2dat = like.s2dat

Nk = len(kdat)
errs = np.diag(like.cov_raw)**0.5
p0err = errs[:Nk]
p2err = errs[Nk:(2*Nk)]
p4err = errs[(2*Nk):(3*Nk)]
v1err = errs[(3*Nk):(4*Nk)]
v3err = errs[(4*Nk):(5*Nk)]
s0err = errs[(5*Nk):(6*Nk)]
s2err = errs[(6*Nk):(7*Nk)]

# %%
bf = like.get_best_fit()

# %%
plt.errorbar(kdat, kdat * p0dat, yerr=kdat*p0err, fmt='o', ms=4, label=r'$P_0$')
plt.errorbar(kdat, kdat * p2dat, yerr=kdat*p2err, fmt='o', ms=4, label=r'$P_2$')
plt.errorbar(kdat, kdat * p4dat, yerr=kdat*p4err, fmt='o', ms=4, label=r'$P_4$')

p0thy = bf[:Nk]
p2thy = bf[Nk:(2*Nk)]
p4thy = bf[(2*Nk):(3*Nk)]

plt.plot(kdat, kdat * p0thy, 'C0')
plt.plot(kdat, kdat * p2thy, 'C1')
plt.plot(kdat, kdat * p4thy, 'C2')

plt.legend(loc='upper right', ncol=3)

plt.xlim(0.02,0.2)
plt.ylim(-100, 1500)

plt.ylabel(r'$k P_\ell(k)$ [$h^{-2}$ Mpc$^2$]')
plt.xlabel(r'$k$ [$h$ Mpc$^{-1}$]')
# Out:
# Text(0.5, 0, '$k$ [$h$ Mpc$^{-1}$]')

# %%
plt.errorbar(kdat, kdat * (p0thy-p0dat), yerr=kdat*p0err, fmt='o', label=r'$P_0$')
plt.errorbar(kdat+0.001, kdat * (p2thy-p2dat), yerr=kdat*p2err, fmt='o', label=r'$P_2$')


plt.plot(kdat, 0*kdat,'k--')
#plt.errorbar(kdat, kdat * p2dat, yerr=kdat*p2err, fmt='o', label=r'$P_2$')
#plt.errorbar(kdat, kdat * p4dat, yerr=kdat*p4err, fmt='o', label=r'$P_4$')

plt.legend()

plt.xlim(0,0.2)
plt.ylim(-100, 100)

plt.ylabel(r'$k P_\ell(k)$ [$h^{-2}$ Mpc$^2$]')
plt.xlabel(r'$k$ [$h$ Mpc$^{-1}$]')
# Out:
# Text(0.5, 0, '$k$ [$h$ Mpc$^{-1}$]')

# %%
plt.errorbar(kdat, -kdat**2 * v1dat, yerr=kdat**2*v1err, fmt='o', label=r'$v_1$')
plt.errorbar(kdat, -kdat**2 * v3dat, yerr=kdat**2*v3err, fmt='o', label=r'$v_3$')

v1thy = bf[(3*Nk):(4*Nk)]
v3thy = bf[(4*Nk):(5*Nk)]

plt.plot(kdat, -kdat**2 * v1thy, 'C0')
plt.plot(kdat, -kdat**2 * v3thy, 'C1')

plt.xlim(0,0.2)
plt.ylim(-100,1000)

plt.legend()
plt.ylabel(r'$k^2 i v_\ell(k)$ [$h^{-2}$ Mpc$^2$]')
plt.xlabel(r'$k$ [$h$ Mpc$^{-1}$]')
# Out:
# Text(0.5, 0, '$k$ [$h$ Mpc$^{-1}$]')

# %%
plt.errorbar(kdat, -kdat**2 * v1dat, yerr=kdat**2*v1err, fmt='o', ms=4, label=r'$v_1$')
plt.errorbar(kdat, -3 * kdat**2 * v3dat, yerr=3 * kdat**2*v3err, fmt='o', ms=4, label=r'$3\times v_3$')

v1thy = bf[(3*Nk):(4*Nk)]
v3thy = bf[(4*Nk):(5*Nk)]

plt.plot(kdat, -kdat**2 * v1thy, 'C0')
plt.plot(kdat, -3 * kdat**2 * v3thy, 'C1')

plt.plot(kdat, -3 * kdat**2 * v3thy, 'C1--')

plt.xlim(0,0.2)
plt.ylim(-100,1000)

plt.legend()
plt.ylabel(r'$k^2 i v_\ell(k)$ [$h^{-2}$ Mpc$^2$]')
plt.xlabel(r'$k$ [$h$ Mpc$^{-1}$]')
# Out:
# Text(0.5, 0, '$k$ [$h$ Mpc$^{-1}$]')

# %%
plt.errorbar(kdat, -kdat**3 * s0dat, yerr=kdat**3*s0err, fmt='o', ms=4, label=r'$\sigma_0$')
plt.errorbar(kdat, -kdat**3 * (s2dat), yerr=kdat**3*(s2err), fmt='o', ms=4, label=r'$\sigma_2$')

s0thy = bf[(5*Nk):(6*Nk)]
s2thy = bf[(6*Nk):(7*Nk)]

plt.plot(kdat, -kdat**3 * s0thy, 'C0')
plt.plot(kdat, -kdat**3 * (s2thy), 'C1')

plt.xlim(0,0.20)
plt.ylim(-500,300)

plt.legend()
plt.ylabel(r'$k^3 i^2 \sigma^2_\ell(k)$ [$h^{-2}$ Mpc$^2$]')
plt.xlabel(r'$k$ [$h$ Mpc$^{-1}$]')
# Out:
# Text(0.5, 0, '$k$ [$h$ Mpc$^{-1}$]')

# %%
from matplotlib.lines import Line2D

# Function to extract components
def extract_components(bf, Nk):
    return {
        'p0': bf[0:Nk],
        'p2': bf[Nk:2*Nk],
        'p4': bf[2*Nk:3*Nk],
        'v1': -bf[3*Nk:4*Nk],
        'v3': -3*bf[4*Nk:5*Nk],
        's0': -bf[5*Nk:6*Nk],
        's2': -bf[6*Nk:7*Nk]
    }

# Extract theory
thy_ept = extract_components(bf, Nk)

# Set up figure
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Panel definitions: [(data_keys, theory_keys, colors, title)]
panels = [
    (['p0','p2'],[r'$P_0$', r'$P_2$', r'$P_4$'], ['C0', 'C1', 'C2']),
    (['v1'],[r'$v_1$', r'$3v_3$'],  ['C0', 'C1']),
    (['s0','s2'],[r'$\sigma^2_0$', r'$\sigma^2_2$'],  ['C0', 'C1'])
]

ylims = [(-50, 1200), (0, 980), (-350, 300)]  # y-limits per panel
kpows = [1, 2, 3]

# Data dict for easy access
data_dict = {
    'p0': (p0dat, p0err),
    'p2': (p2dat, p2err),
    'p4': (p4dat, p4err),
    'v1': (-v1dat, v1err),
    'v3': (-3*v3dat, v3err),
    's0': (-s0dat, s0err),
    's2': (-s2dat, s2err)
}

# Plot each panel
for i, (data_keys, legends, colors) in enumerate(panels):

    ax = axes[i]
    
    # Plot data and theory
    for j, key in enumerate(data_keys):
        dat, err = data_dict[key]
        ax.errorbar(kdat, kdat**kpows[i] * dat, yerr=kdat**kpows[i] * err, fmt='o', ms=4, color=colors[j], label=legends[j])

        ax.plot(kdat, kdat**kpows[i] * thy_ept[key], color=colors[j], linestyle='-')

    ax.set_xlim(0.00, 0.2)
    ax.set_ylim(*ylims[i])
    #ax.set_title(title)
    ax.set_xlabel(r'$k$ [$h$ Mpc$^{-1}$]')
    if i == 0:
        ax.set_ylabel(r'$i^n k^{n+1} \Xi^{(n)}_\ell$ [$h^{-2}$ Mpc$^2$]')

    if i != 2:
        ax.legend(ncol=4, loc='upper right')
    else:
        # Get existing legend handles/labels
        handles, labels = ax.get_legend_handles_labels()

        # Add EPT/LPT style indicators
        handles += [
        Line2D([0], [0], color='k', linestyle='-', label='EPT'),
        Line2D([0], [0], color='k', linestyle='--', label='LPT')
        ]
        labels += ['EPT', 'LPT']

        ax.legend(handles, labels, ncol=4, loc='upper right')

plt.tight_layout()
plt.show()


#plt.savefig('Figures/fits_z_0p1_logM_12p5_13p0.pdf')

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 8), sharex='col', gridspec_kw={'height_ratios': [4, 1]})

for i, (data_keys, legends, colors) in enumerate(panels):
    ax = axes[0, i]
    ax_res = axes[1, i]

    for j, key in enumerate(data_keys):
        dat, err = data_dict[key]

        # Plot data and theory
        ax.errorbar(kdat, kdat**kpows[i] * dat, yerr=kdat**kpows[i] * err, fmt='o', ms=4, color=colors[j], label=legends[j])
        ax.plot(kdat, kdat**kpows[i] * thy_ept[key], color=colors[j], linestyle='-')

        # Residuals
        ept_resid = (dat - thy_ept[key]) / (err)

        ax_res.axhline(0, color='k', lw=1, ls=':')
        ax_res.plot(kdat, ept_resid, color=colors[j], linestyle='-')

    # Main panel formatting
    ax.set_xlim(0.00, 0.15)
    ax.set_ylim(*ylims[i])
    if i == 0:
        ax.set_ylabel(r'$i^n k^{n+1} \Xi^{(n)}_\ell$ [$h^{-2}$ Mpc$^2$]')

    if i == 1:
        ax.text(0.025, 50, r'$z, M_{min}, M_{max} = 0.1, 12.5, 13.0$')
    
    if i != 2:
        ax.legend(ncol=4, loc='upper right')
    else:
        handles, labels = ax.get_legend_handles_labels()
        handles += [Line2D([0], [0], color='k', linestyle='-', label='EPT'),
                    Line2D([0], [0], color='k', linestyle='--', label='LPT')]
        labels += ['EPT', 'LPT']
        ax.legend(handles, labels, ncol=2, loc='upper right')

    # Residual panel formatting
    ax_res.set_xlim(0.00, 0.15)
    ax_res.set_ylim(-1, 1)
    ax_res.fill_between([-10,10],[-0.2, -0.2], [0.2,0.2], color='k', alpha=0.3)
    ax_res.set_xlabel(r'$k$ [$h$ Mpc$^{-1}$]')
    if i == 0:
        ax_res.set_ylabel(r'$(\hat{\Xi}^{(n)}_\ell - \Xi^{(n)}_{\ell, \rm th}) / \sigma$')

plt.tight_layout()
plt.savefig('Figures/fits_z_bestfit_0p1_logM_12p5_13p0.pdf')
plt.show()

# %%
thy = model.theory['pairwise_velocity_likelihood_am.PT_Theory']
modPT = thy.current_state['ptmod']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 thy = model.theory['pairwise_velocity_likelihood_am.PT_Theory']
#       2 modPT = thy.current_state['ptmod']
#
# KeyError: 'pairwise_velocity_likelihood_am.PT_Theory'

# %%
fz = info['params']['fz']['value']
b1 = bf_params['b1']

klin = modPT.ept.kv
plin= modPT.ept.plin
plin_w = modPT.ept.plin - modPT.ept_nw.plin

# %%
modPT.ept_nw.compute_Xiells_redshift_space()

pvec = [bf_params['b1'], bf_params['b2'], bf_params['bs']]
pvec += list(like.bf_thetas)

sellnws = modPT.combine_bias_terms(pvec,modPT.ept_nw.sselltable,)
vellnws = modPT.combine_bias_terms(pvec,modPT.ept_nw.vselltable,)

# %%
from scipy.interpolate import interp1d

v1nw = interp1d(modPT.kv, vellnws[1,:], kind='cubic')(kdat)
v3nw = interp1d(modPT.kv, vellnws[3,:], kind='cubic')(kdat)


s0nw = interp1d(modPT.kv, sellnws[0,:], kind='cubic')(kdat)
s2nw = interp1d(modPT.kv, sellnws[2,:], kind='cubic')(kdat)

# %%
from scipy.optimize import curve_fit

pfunc = lambda x, a, b, c, d: a*x**2 + b*x**4 + c*x**6 + d*x**8
pfunc = lambda x, a, b, c: a*x**2 + b*x**4 + c*x**6

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6), )

# Define common k-range for broadband fit
kbb = 0.15
kfit = kdat[kdat < kbb]

# Panel 1: v1
ax = axes[0]
v1thy = bf[(3*Nk):(4*Nk)]
v1lpt = bf_lpt[(3*Nk):(4*Nk)]

Delta = -kdat**2 * (v1thy - v1nw) - (-kdat**2 * (v1dat - v1nw))
res = curve_fit(pfunc, kfit, Delta[kdat < kbb])[0]
bband = pfunc(kdat, *res)

ax.plot(kdat, -kdat**2 * (v1thy - v1nw) - bband, 'C0',label='EPT')
ax.plot(kdat, - bband, 'C0:')


Delta = -kdat**2 * (v1lpt - v1nw) - (-kdat**2 * (v1dat - v1nw))
res = curve_fit(pfunc, kfit, Delta[kdat < kbb])[0]
bband = pfunc(kdat, *res)

ax.plot(kdat, -kdat**2 * (v1lpt - v1nw) - bband, 'C1')
ax.plot(kdat, - bband, 'C1:')


#ax.plot(kdat, bband, 'k:')
ax.errorbar(kdat, -kdat**2 * (v1dat - v1nw) + 0*bband, yerr=kdat**2 * v1err, fmt='o')
ax.plot(klin, -klin**2 * (-2 * (b1*fz + 3*fz**2/5) * plin_w / klin), 'k--')
ax.set_xlim(0, 0.15)
ax.set_ylim(-80, 80)
ax.set_ylabel(r'$k^2 i v_{1,w}(k)$ [$h^{-2}$ Mpc$^2$]')
ax.legend()

# Panel 2: σ₀
ax = axes[1]
s0thy = bf[(5*Nk):(6*Nk)]
s0lpt = bf_lpt[(5*Nk):(6*Nk)]

Delta = -kdat**3 * (s0thy - s0nw) - (-kdat**3 * (s0dat - s0nw))
res = curve_fit(pfunc, kfit, Delta[kdat < kbb])[0]
bband = pfunc(kdat, *res)

ax.plot(kdat, -kdat**3 * (s0thy - s0nw) - bband, 'C0')
ax.plot(kdat, - bband, 'C0:')


Delta = -kdat**3 * (s0lpt - s0nw) - (-kdat**3 * (s0dat - s0nw))
res = curve_fit(pfunc, kfit, Delta[kdat < kbb])[0]
bband = pfunc(kdat, *res)

ax.plot(kdat, -kdat**3 * (s0lpt - s0nw) - bband, 'C1',label='LPT')
ax.plot(kdat, - bband, 'C1:')

#ax.plot(kdat, bband, 'k:')
ax.errorbar(kdat, -kdat**3 * (s0dat - s0nw) + 0*bband, yerr=kdat**3 * s0err, fmt='o')
ax.plot(klin, -klin**3 * (-2./3 * fz**2 * plin_w / klin**2), 'k--')
ax.set_xlim(0, 0.15)
ax.set_ylim(-30, 30)
ax.legend()
ax.set_ylabel(r'$k^3 i^2 \sigma^2_{w,0}(k)$ [$h^{-2}$ Mpc$^2$]')

ax.text(0.015, -25, r'$z, M_{min}, M_{max} = 0.1, 12.5, 13.0$')
    

# Panel 3: σ₂
ax = axes[2]
s2thy = bf[(6*Nk):(7*Nk)]
s2lpt = bf_lpt[(6*Nk):(7*Nk)]

Delta = -kdat**3 * (s2thy - s2nw) - (-kdat**3 * (s2dat - s2nw))
res = curve_fit(pfunc, kfit, Delta[kdat < kbb])[0]
bband = pfunc(kdat, *res)

ax.plot(kdat, -kdat**3 * (s2thy - s2nw) - bband, 'C0')
ax.plot(kdat, - bband, 'C0:')

Delta = -kdat**3 * (s2lpt - s2nw) - (-kdat**3 * (s2dat - s2nw))
res = curve_fit(pfunc, kfit, Delta[kdat < kbb])[0]
bband = pfunc(kdat, *res)

ax.plot(kdat, -kdat**3 * (s2lpt - s2nw) - bband, 'C1')
ax.plot(kdat, - bband, 'C1:')


ax.plot(-5, -5, 'k:',label='broadband')
ax.errorbar(kdat, -kdat**3 * (s2dat - s2nw) + 0*bband, yerr=kdat**3 * s0err, fmt='o')  # double-check: s0err or s2err?
ax.plot(klin, -klin**3 * (-4./3 * fz**2 * plin_w / klin**2), 'k--', label='linear')
ax.set_xlim(0, 0.15)
ax.set_ylim(-30, 30)
ax.legend(loc='upper right')
ax.set_ylabel(r'$k^3 i^2 \sigma^2_{w,2}(k)$ [$h^{-2}$ Mpc$^2$]')

# Common x-label
for ax in axes:
    ax.set_xlabel(r'$k$ [$h$ Mpc$^{-1}$]')

plt.tight_layout()
plt.savefig('Figures/wiggles_z_0p1_logM_12p5_13p0.pdf')
plt.show()

# %%
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /global/homes/s/sfschen/.conda/envs/pcobaya/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
